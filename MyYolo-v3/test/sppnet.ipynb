# %%
import sys
sys.path.append("..")
from models import SppNet
from torchsummary import summary

# %%
net = SppNet()
net
# Out:
# SppNet(
#   (backbone): Identity()
#   (cblset_pre): Sequential(
#     (cbl_num0): ConvBL(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False, padding_mode=replicate)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.1)
#     )
#     (cbl_num1): ConvBL(
#       (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=replicate)
#       (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.1)
#     )
#     (cbl_num2): ConvBL(
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False, padding_mode=replicate)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.1)
#     )
#   )
# ...

# %%
summary(net, [(256, 64, 64), (512, 32, 32), (1024, 16, 16)], device="cpu")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#           Identity-1         [-1, 1024, 16, 16]               0
#             Conv2d-2          [-1, 512, 16, 16]         524,288
#        BatchNorm2d-3          [-1, 512, 16, 16]           1,024
#          LeakyReLU-4          [-1, 512, 16, 16]               0
#             ConvBL-5          [-1, 512, 16, 16]               0
#             Conv2d-6         [-1, 1024, 16, 16]       4,718,592
#        BatchNorm2d-7         [-1, 1024, 16, 16]           2,048
#          LeakyReLU-8         [-1, 1024, 16, 16]               0
#             ConvBL-9         [-1, 1024, 16, 16]               0
#            Conv2d-10          [-1, 512, 16, 16]         524,288
#       BatchNorm2d-11          [-1, 512, 16, 16]           1,024
#         LeakyReLU-12          [-1, 512, 16, 16]               0
#            ConvBL-13          [-1, 512, 16, 16]               0
# ...
