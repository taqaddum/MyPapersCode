# %%
import sys
sys.path.append("..")
from models import YOLOSpp
from torchsummary import summary

# %%
net = YOLOSpp(3, 10, 3)
net
# Out:
# YOLOSpp(
#   (yolo_body): DarkNet53(
#     (cbl): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=replicate)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.1)
#     )
#     (resblock0): Sequential(
#       (cbl): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=replicate)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1)
#       )
#       (resunit0): CBLResidual(
#         (cbl_1): Sequential(
#           (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): LeakyReLU(negative_slope=0.1)
#         )
#         (cbl_2): Sequential(
# ...

# %%
summary(net, (3, 512, 512), device="cpu")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 512, 512]             864
#        BatchNorm2d-2         [-1, 32, 512, 512]              64
#          LeakyReLU-3         [-1, 32, 512, 512]               0
#             Conv2d-4         [-1, 64, 256, 256]          18,432
#        BatchNorm2d-5         [-1, 64, 256, 256]             128
#          LeakyReLU-6         [-1, 64, 256, 256]               0
#             Conv2d-7         [-1, 32, 256, 256]           2,048
#        BatchNorm2d-8         [-1, 32, 256, 256]              64
#          LeakyReLU-9         [-1, 32, 256, 256]               0
#            Conv2d-10         [-1, 64, 256, 256]          18,432
#       BatchNorm2d-11         [-1, 64, 256, 256]             128
#         LeakyReLU-12         [-1, 64, 256, 256]               0
#       CBLResidual-13         [-1, 64, 256, 256]               0
# ...

# %%
list(net.children())
# Out:
# [DarkNet53(
#    (cbl): Sequential(
#      (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=replicate)
#      (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (2): LeakyReLU(negative_slope=0.1)
#    )
#    (resblock0): Sequential(
#      (cbl): Sequential(
#        (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=replicate)
#        (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (2): LeakyReLU(negative_slope=0.1)
#      )
#      (resunit0): CBLResidual(
#        (cbl_1): Sequential(
#          (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#          (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#          (2): LeakyReLU(negative_slope=0.1)
#        )
#        (cbl_2): Sequential(
# ...
